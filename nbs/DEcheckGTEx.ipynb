# %%
import polars as pl

pl.scan_csv("/Users/edeneldar/Library/CloudStorage/GoogleDrive-edenede2@gmail.com/My Drive/Shaked's src/Code/inter-tissue-aging-main/key_modules_genes.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/fsl/lib/python3.11/site-packages/polars/lazyframe/frame.py:785, in LazyFrame._repr_html_(self)
#     784 try:
# --> 785     dot = self._ldf.to_dot(optimized=False)
#     786     svg = subprocess.check_output(
#     787         ["dot", "-Nshape=box", "-Tsvg"], input=f"{dot}".encode()
#     788     )
#
# FileNotFoundError: No such file or directory (os error 2): ...nede2@gmail.com/My Drive/Shaked's src/Code/inter-tissue-aging-main/key_modules_genes.csv (set POLARS_VERBOSE=1 to see full path)
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/fsl/lib/python3.11/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
# ...
